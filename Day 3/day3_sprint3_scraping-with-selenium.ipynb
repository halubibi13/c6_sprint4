# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests
import re

# %%
PATH = r'E:/Downloads/chromedriver_win32/chromedriver.exe'
driver = webdriver.Chrome(PATH)
driver.get('https://www.google.com/')
search = driver.find_element_by_name('q')
search.send_keys('Eskwelabs')
search.send_keys(Keys.RETURN)

driver.find_elements_by_xpath("//a[@href='https://www.eskwelabs.com/']")[0].click()

time.sleep(5)

x = driver.page_source

driver.quit()

# %%
x
# Out:
# '<html><head><title>Eskwelabs - Data education for the future of work</title><meta charset="utf-8"><link rel="icon" href="/favicon.png"><meta name="viewport" content="initial-scale=1.0, width=device-width, maximum-scale=1.0, user-scalable=no"><link rel="preconnect" href="https://fonts.gstatic.com"><link href="https://fonts.googleapis.com/css2?family=Libre+Franklin:ital,wght@0,400;0,500;0,600;1,400;1,600&amp;family=Saira:wght@400;500;600&amp;display=swap" rel="stylesheet"><meta name="title" content="Eskwelabs - Data education for the future of work"><meta name="description" content="Eskwelabs is Southeast Asia’s data upskilling school. We bring together the best of online &amp; community-based learning to help teams and individuals access opportunities in the future of work."><meta property="og:type" content="website"><meta property="og:url" content="https://www.eskwelabs.com"><meta property="og:title" content="Eskwelabs - Data education for the future of work"><meta property="og:description" content="Eskwelabs is Southeast Asia’s data upskilling school. We bring together the best of online &amp; community-based learning to help teams and individuals access opportunities in the future of work."><meta property="og:image" content="https://assets.eskwelabs.com/talent-is-everywhere.jpg"><meta property="twitter:card" content="summary_large_image"><meta property="twitter:url" content="https://www.eskwelabs.com"><meta property="twitter:title" content="Eskwelabs - Data education for the future of work"><meta property="twitter:description" content="Eskwelabs is Southeast Asia’s data upskilling school. We bring together the best of online &amp; community-based learning to help teams and individuals access opportunities in the future of work."><meta property="twitter:image" content="https://assets.eskwelabs.com/talent-is-everywhere.jpg"><meta charset="utf-8"><script type="text/javascript" async="" src="https://www.googleadservices.com/pagead/conversion_async.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=AW-675108631&amp;l=dataLayer&amp;cx=c"></script><script async="true" src="https://www.googletagmanager.com/gtag/js?id=undefined"></script><script async="true">\n        window.dataLayer = window.dataLayer || [];\n        function gtag(){dataLayer.push(arguments);}\n        gtag(\'js\', new Date());\n\n        gtag("config", "undefined");\n        gtag(\'config\', "undefined");\n\n        </script><script async="true">\n        (function (h, o, t, j, a, r) {\n          h.hj =\n            h.hj ||\n            function () {\n              (h.hj.q = h.hj.q || []).push(arguments);\n            };\n          h._hjSettings = { hjid: 1828133, hjsv: 6 };\n          a = o.getElementsByTagName("head")[0];\n          r = o.createElement("script");\n          r.async = 1;\n          r.src = t + h._hjSettings.hjid + j + h._hjSettings.hjsv;\n          a.appendChild(r);\n        })(window, document, "https://static.hotjar.com/c/hotjar-", ".js?sv=");</script><script async="true">\n        !(function (f, b, e, v, n, t, s) {\n          if (f.fbq) return;\n          n = f.fbq = function () {\n            n.callMethod\n              ? n.callMethod.apply(n, arguments)\n              : n.queue.push(arguments);\n          };\n          if (!f._fbq) f._fbq = n;\n          n.push = n;\n          n.loaded = !0;\n          n.version = "2.0";\n          n.queue = [];\n          t = b.createElement(e);\n          t.async = !0;\n          t.src = v;\n          s = b.getElementsByTagName(e)[0];\n          s.parentNode.insertBefore(t, s);\n        })(\n          window,\n          document,\n          "script",\n          "https://connect.facebook.net/en_US/fbevents.js"\n        );\n        fbq("init", "2425447234370333");\n        fbq("track", "PageView");\n        </script><meta name="next-head-count" content="21"><link rel="preload" href="/_next/static/css/199f56beb0826cec721a.css" as="style"><link rel="styleshee ...

# %%
soup = BeautifulSoup(x, 'lxml')

# %%
contents = soup.find_all('blockquote', class_="relative flex-grow p-8 w-full text-base tracking-wide leading-6")

contents[1].find_all('p')[0]
# Out:
# <p>Through Eskwelabs, I developed a <em><strong>data-driven mindset</strong></em> and a greater passion for learning.</p>

# %%
type(contents[1].find_all('p')[0])
# Out:
# bs4.element.Tag

# %%
contents[1].find_all('p')[0].get_text()
# Out:
# 'Through Eskwelabs, I developed a data-driven mindset and a greater passion for learning.'

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Eskwelabs - Data education for the future of work
#   </title>
#   <meta charset="utf-8"/>
#   <link href="/favicon.png" rel="icon"/>
#   <meta content="initial-scale=1.0, width=device-width, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <link href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link href="https://fonts.googleapis.com/css2?family=Libre+Franklin:ital,wght@0,400;0,500;0,600;1,400;1,600&amp;family=Saira:wght@400;500;600&amp;display=swap" rel="stylesheet"/>
#   <meta content="Eskwelabs - Data education for the future of work" name="title"/>
#   <meta content="Eskwelabs is Southeast Asia’s data upskilling school. We bring together the best of online &amp; community-based learning to help teams and individuals access opportunities in the future of work." name="description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.eskwelabs.com" property="og:url"/>
#   <meta content="Eskwelabs - Data education for the future of work" property="og:title"/>
#   <meta content="Eskwelabs is Southeast Asia’s data upskilling school. We bring together the best of online &amp; community-based learning to help teams and individuals access opportunities in the future of work." property="og:description"/>
#   <meta content="https://assets.eskwelabs.com/talent-is-everywhere.jpg" property="og:image"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="https://www.eskwelabs.com" property="twitter:url"/>
#   <meta content="Eskwelabs - Data education for the future of work" property="twitter:title"/>
#   <meta content="Eskwelabs is Southeast Asia’s data upskilling school. We bring together the best of online &amp; community-based learning to help teams and individuals access opportunities in the future of work." property="twitter:description"/>
#   <meta content="https://assets.eskwelabs.com/talent-is-everywhere.jpg" property="twitter:image"/>
#   <meta charset="utf-8"/>
#   <script async="" src="https://www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-675108631&amp;l=dataLayer&amp;cx=c" type="text/javascript">
#   </script>
#   <script async="true" src="https://www.googletagmanager.com/gtag/js?id=undefined">
#   </script>
#   <script async="true">
#    window.dataLayer = window.dataLayer || [];
#         function gtag(){dataLayer.push(arguments);}
#         gtag('js', new Date());
#
#         gtag("config", "undefined");
#         gtag('config', "undefined");
#   </script>
#   <script async="true">
#    (function (h, o, t, j, a, r) {
#           h.hj =
#             h.hj ||
#             function () {
#               (h.hj.q = h.hj.q || []).push(arguments);
#             };
#           h._hjSettings = { hjid: 1828133, hjsv: 6 };
#           a = o.getElementsByTagName("head")[0];
#           r = o.createElement("script");
#           r.async = 1;
#           r.src = t + h._hjSettings.hjid + j + h._hjSettings.hjsv;
#           a.appendChild(r);
#         })(window, document, "https://static.hotjar.com/c/hotjar-", ".js?sv=");
#   </script>
#   <script async="true">
#    !(function (f, b, e, v, n, t, s) {
#           if (f.fbq) return;
#           n = f.fbq = function () {
#             n.callMethod
#               ? n.callMethod.apply(n, arguments)
#               : n.queue.push(arguments);
#           };
#           if (!f._fbq) f._fbq = n;
#           n.push = n;
#           n.loaded = !0;
#           n.version = "2.0";
#           n.queue = [];
#           t = b.createElement(e);
#           t.async = !0;
#           t.src = v;
#           s = b.getElementsByTagName(e)[0];
#           s.parentNode.insertBefore(t, s);
#         })(
#           window,
#           document,
#           "script",
#           "https://connect.facebook.net/en_US/fbevents.js"
#         );
#         fbq("init", "2425447234370333");
#         fbq("track", "PageView");
#   </script>
#   <meta content="21" name="next-head-count"/>
#   <link as="style" href="/_next/static/css/199f56beb0826cec721a.css" rel="preload"/>
#   <link data-n-g="" href="/_next/static/css/199f56beb0826cec721a.css" rel="stylesheet"/>
#   <noscript data-n-css="">
#   </noscript>
#   <link as="script" href="/_next/static/chunks/main-63b4da518a06488ffb50.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/webpack-cb40b0c47a0047965a08.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/framework.9707fddd9ae5927c17c3.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/commons.10a9314202ca8629b33c.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/74e6a81e666a4a4de28a244888c091c5eb13391e.99073904f647c8c9f0f3.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/pages/_app-68ea9945159d2922b21a.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/35b6b5a93b9b89ca812d02ec8c2964793e86ba01.5be50b8eaed33eb905de.js" rel="preload"/>
#   <link as="script" href="/_next/static/chunks/pages/index-254fb798efa03823cc2b.js" rel="preload"/>
#   <script async="" src="https://static.hotjar.com/c/hotjar-1828133.js?sv=6">
#   </script>
#   <link as="script" href="/_next/static/chunks/35b6b5a93b9b89ca812d02ec8c2964793e86ba01.5be50b8eaed33eb905de.js" rel="prefetch"/>
#   <link as="script" href="/_next/static/chunks/pages/index-254fb798efa03823cc2b.js" rel="prefetch"/>
#   <link as="script" href="/_next/static/chunks/47f4fe5087d09f58e9f22a4202f3069e8af1fccf.9792c339b179631a910c.js" rel="prefetch"/>
#   <link as="script" href="/_next/static/chunks/pages/about-99aae1f9f114f267fa55.js" rel="prefetch"/>
#   <link as="script" href="/_next/static/chunks/2dc2263451bebce49644f8d901e6a7cd4fbc31ef.365508483d4ac1f615e6.js" rel="prefetch"/>
#   <link as="script" href="/_next/static/chunks/pages/for-companies-4c648f08fb6b61789779.js" rel="prefetch"/>
#   <link as="script" href="/_next/static/chunks/pages/careers-243a9b95d31f56266446.js" rel="prefetch"/>
#   <link as="script" href="/_next/static/chunks/pages/blog-db0c0aa50467462bc1cf.js" rel="prefetch"/>
#   <script async="" charset="utf-8" src="https://script.hotjar.com/modules.4f372e984ed758fa9d73.js">
#   </script>
#   <style type="text/css">
#    iframe#_hjRemoteVarsFrame {display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;}
#   </style>
#   <script async="" src="https://connect.facebook.net/signals/config/2425447234370333?v=2.9.33&amp;r=stable">
#   </script>
#   <script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/675108631/?random=1614769564777&amp;cv=9&amp;fst=1614769564777&amp;num=1&amp;bg=ffffff&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=720&amp;u_w=1280&amp;u_ah=680&amp;u_aw=1280&amp;u_cd=24&amp;u_his=4&amp;u_tz=480&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2oa2h0&amp;sendb=1&amp;ig=1&amp;data=event%3Dgtag.config&amp;frm=0&amp;url=https%3A%2F%2Fwww.eskwelabs.com%2F&amp;ref=https%3A%2F%2Fwww.google.com%2F&amp;tiba=Eskwelabs%20-%20Data%20education%20for%20the%20future%20of%20work&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4">
#   </script>
#   <script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/675108631/?random=1614769564787&amp;cv=9&amp;fst=1614769564787&amp;num=1&amp;bg=ffffff&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=720&amp;u_w=1280&amp;u_ah=680&amp;u_aw=1280&amp;u_cd=24&amp;u_his=4&amp;u_tz=480&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2oa2h0&amp;sendb=1&amp;ig=1&amp;data=event%3Doptimize.callback&amp;frm=0&amp;url=https%3A%2F%2Fwww.eskwelabs.com%2F&amp;ref=https%3A%2F%2Fwww.google.com%2F&amp;tiba=Eskwelabs%20-%20Data%20education%20for%20the%20future%20of%20work&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4">
#   </script>
#   <link as="script" href="/_next/static/chunks/6eaf201f56d173ece524a6c619a74538491fc9b5.524b501f32184771b75a.js" rel="prefetch"/>
#   <link as="script" href="/_next/static/chunks/pages/aral-aral-a952719a4b0d95b0595c.js" rel="prefetch"/>
#   <link as="script" href="/_next/static/chunks/pages/aral-aral-plus-bb1bd7d5b9eed3582e91.js" rel="prefetch"/>
#   <link as="script" href="/_next/static/chunks/pages/data-analytics-bootcamp-a82282c115e6c525e3ed.js" rel="prefetch"/>
#   <link as="script" href="/_next/static/chunks/pages/data-science-fellowship-14b0aac3f918cdc1e7fc.js" rel="prefetch"/>
#   <link as="script" href="/_next/static/chunks/pages/data-club-42645142e76ce1c7dbc4.js" rel="prefetch"/>
#   <link as="script" href="/_next/static/chunks/pages/blog/%5Bslug%5D-ba01b9aefea2eb9744e0.js" rel="prefetch"/>
#   <link as="script" href="/_next/static/chunks/pages/privacy-6ef864fceb27014cfe64.js" rel="prefetch"/>
#  </head>
#  <body>
#   <div id="__next">
#    <div>
#     <div class="transition-all duration-500 header fixed z-50 px-8 py-3 w-full text-black bg-white border-mercury border-b">
#      <div class="flex flex-row justify-between mx-auto max-w-screen-2xl h-full md:items-center">
#       <button class="focus:shadow-outline w-6 h-6 rounded-lg focus:outline-none md:hidden">
#        <svg class="w-4 h-4 fill-current" viewbox="0 0 448 512">
#         <path d="M16 132h416c8.837 0 16-7.163 16-16V76c0-8.837-7.163-16-16-16H16C7.163 60 0 67.163 0 76v40c0 8.837 7.163 16 16 16zm0 160h416c8.837 0 16-7.163 16-16v-40c0-8.837-7.163-16-16-16H16c-8.837 0-16 7.163-16 16v40c0 8.837 7.163 16 16 16zm0 160h416c8.837 0 16-7.163 16-16v-40c0-8.837-7.163-16-16-16H16c-8.837 0-16 7.163-16 16v40c0 8.837 7.163 16 16 16z">
#         </path>
#        </svg>
#       </button>
#       <a href="/">
#        <svg class="h-7 fill-current md:h-9" height="36px" viewbox="0 0 149.458 36" width="149.458px" x="0px" xmlns="http://www.w3.org/2000/svg" y="0px">
viewbox="0 0 320 512" xmlns="http://www.w3.org/2000/svg">
#           <path d="M143 352.3L7 216.3c-9.4-9.4-9.4-24.6 0-33.9l22.6-22.6c9.4-9.4 24.6-9.4 33.9 0l96.4 96.4 96.4-96.4c9.4-9.4 24.6-9.4 33.9 0l22.6 22.6c9.4 9.4 9.4 24.6 0 33.9l-136 136c-9.2 9.4-24.4 9.4-33.8 0z">
#           </path>
#          </svg>
#         </div>
#         <nav class="fixed text-black bg-white border-mercury border-b">
#          <div class="link">
#           Aral-Aral
#          </div>
#          <div class="link">
#           Aral-Aral Plus
#          </div>
#          <div class="link">
#           Data Analytics Bootcamp
#          </div>
#          <div class="link">
#           Data Science Fellowship
#          </div>
#          <div class="link">
#           Data Club
#          </div>
#         </nav>
#        </div>
#        <div class="link">
#         For Companies
#        </div>
#        <a href="/careers">
#         <div class="link">
#          Careers
#         </div>
#        </a>
#        <div class="link">
#         Blog
#        </div>
#       </nav>
#       <div class="md:hidden text-white">
#        <svg class="ml-4 px-2 py-2 h-7 fill-current" viewbox="0 0 512 512" xmlns="http://www.w3.org/2000/svg">
#         <path d="M505 442.7L405.3 343c-4.5-4.5-10.6-7-17-7H372c27.6-35.3 44-79.7 44-128C416 93.1 322.9 0 208 0S0 93.1 0 208s93.1 208 208 208c48.3 0 92.7-16.4 128-44v16.3c0 6.4 2.5 12.5 7 17l99.7 99.7c9.4 9.4 24.6 9.4 33.9 0l28.3-28.3c9.4-9.4 9.4-24.6.1-34zM208 336c-70.7 0-128-57.2-128-128 0-70.7 57.2-128 128-128 70.7 0 128 57.2 128 128 0 70.7-57.2 128-128 128z">
#         </path>
#        </svg>
#       </div>
#      </div>
#      <nav class="hidden flex-col flex-grow pb-4 transition-transform">
#       <a href="/about">
#        <div class="link">
#         About Us
#        </div>
#       </a>
#       <button class="link rotate-180-svg-active flex flex-row uppercase focus:outline-none">
#        For Learners
#        <svg class="px-2 py-0 fill-current" style="height:14px" viewbox="0 0 320 512" xmlns="http://www.w3.org/2000/svg">
#         <path d="M143 352.3L7 216.3c-9.4-9.4-9.4-24.6 0-33.9l22.6-22.6c9.4-9.4 24.6-9.4 33.9 0l96.4 96.4 96.4-96.4c9.4-9.4 24.6-9.4 33.9 0l22.6 22.6c9.4 9.4 9.4 24.6 0 33.9l-136 136c-9.2 9.4-24.4 9.4-33.8 0z">
#         </path>
#        </svg>
#       </button>
#       <div class="hidden ml-4 border-l border-mischka">
#        <div class="link">
#         Aral-Aral
#        </div>
#        <div class="link">
#         Aral-Aral Plus
#        </div>
#        <div class="link">
#         Data Analytics Bootcamp
#        </div>
#        <div class="link">
#         Data Science Fellowship
#        </div>
#        <div class="link">
#         Data Club
#        </div>
#       </div>
#       <div class="link">
#        For Companies
#       </div>
#       <a href="/careers">
#        <div class="link">
#         Careers
#        </div>
#       </a>
#       <div class="link">
#        Blog
#       </div>
#      </nav>
#     </div>
#     <main>
#      <div>
#       <section>
#        <div class="background-image mt-7 md:mt-0">
#         <div style="display:block;overflow:hidden;position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;margin:0">
#          <img alt="Talent is everywhere" class="object-scale-down md:object-cover" decoding="async" sizes="(max-width: 640px) 640px, (max-width: 750px) 750px, (max-width: 828px) 828px, (max-width: 1080px) 1080px, (max-width: 1200px) 1200px, (max-width: 1920px) 1920px, (max-width: 2048px) 2048px, 3840px" src="/_next/image?url=%2Fimages%2Ftalent-is-everywhere.jpg&amp;w=3840&amp;q=75" srcset="/_next/image?url=%2Fimages%2Ftalent-is-everywhere.jpg&amp;w=640&amp;q=75 640w, /_next/image?url=%2Fimages%2Ftalent-is-everywhere.jpg&amp;w=750&amp;q=75 750w, /_next/image?url=%2Fimages%2Ftalent-is-everywhere.jpg&amp;w=828&amp;q=75 828w, /_next/image?url=%2Fimages%2Ftalent-is-everywhere.jpg&amp;w=1080&amp;q=75 1080w, /_next/image?url=%2Fimages%2Ftalent-is-everywhere.jpg&amp;w=1200&amp;q=75 1200w, /_next/image?url=%2Fimages%2Ftalent-is-everywhere.jpg&amp;w=1920&amp;q=75 1920w, /_next/image?url=%2Fimages%2Ftalent-is-everywhere.jpg&amp;w=2048&amp;q=75 2048w, /_next/image?url=%2Fimages%2Ftalent-is-everywhere.jpg&amp;w=3840&amp;q=75 3840w" style="visibility: visible; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-position: center top;"/>
#         </div>
#        </div>
#        <div class="home-hero-style">
#         <div class="container grid gap-4 mx-auto xl:grid-cols-3">
#          <aside class="mt-64 md:mb-32 md:mt-64 xl:col-start-3">
#           <h1 class="hero-heading-letter-spacing mb-12 text-2xl leading-none md:text-5xl">
#            <span>
#             The future of work is data
#            </span>
#           </h1>
#           <p class="mb-12 text-sm md:text-xl">
#            <span>
#             Eskwelabs is an online data upskilling school for people and teams in Southeast Asia
#            </span>
#           </p>
#           <button class="button mb-4 mr-4">
#            For Individuals
#           </button>
#           <button class="button">
#            For Companies
#           </button>
#          </aside>
#         </div>
#        </div>
#       </section>
#       <section class="bg-white">
#        <section class="container grid gap-4 mx-auto px-8 py-12 bg-zircon shadow-md md:relative md:-top-8 md:grid-cols-4 md:rounded-lg">
#         <div class="px-4 py-2">
#          <h3 class="mb-2 text-pickled-bluewood text-2xl leading-9">
#           What We Offer
#          </h3>
#          <p class="text-justify text-tundora text-sm tracking-wider leading-7">
#           Access opportunities in the future of work through accessible data skills that are high in-demand as the amount of data in the world increases exponentially.
#          </p>
#         </div>
#         <div class="px-4 py-6 border-t border-mischka md:py-4 md:border-l md:border-t-0">
#          <div class="mb-1 p-2 w-8 text-white bg-tradewind rounded-full fill-current">
#           <svg viewbox="0 0 640 512" xmlns="http://www.w3.org/2000/svg">
#            <path d="M621.16 54.46C582.37 38.19 543.55 32 504.75 32c-123.17-.01-246.33 62.34-369.5 62.34-30.89 0-61.76-3.92-92.65-13.72-3.47-1.1-6.95-1.62-10.35-1.62C15.04 79 0 92.32 0 110.81v317.26c0 12.63 7.23 24.6 18.84 29.46C57.63 473.81 96.45 480 135.25 480c123.17 0 246.34-62.35 369.51-62.35 30.89 0 61.76 3.92 92.65 13.72 3.47 1.1 6.95 1.62 10.35 1.62 17.21 0 32.25-13.32 32.25-31.81V83.93c-.01-12.64-7.24-24.6-18.85-29.47zM48 132.22c20.12 5.04 41.12 7.57 62.72 8.93C104.84 170.54 79 192.69 48 192.69v-60.47zm0 285v-47.78c34.37 0 62.18 27.27 63.71 61.4-22.53-1.81-43.59-6.31-63.71-13.62zM320 352c-44.19 0-80-42.99-80-96 0-53.02 35.82-96 80-96s80 42.98 80 96c0 53.03-35.83 96-80 96zm272 27.78c-17.52-4.39-35.71-6.85-54.32-8.44 5.87-26.08 27.5-45.88 54.32-49.28v57.72zm0-236.11c-30.89-3.91-54.86-29.7-55.81-61.55 19.54 2.17 38.09 6.23 55.81 12.66v48.89z">
#            </path>
#           </svg>
#          </div>
#          <h4 class="leading-2 my-2 text-pickled-bluewood text-sm">
#           Affordable Outcomes
#          </h4>
#          <p class="text-justify text-tundora text-xs tracking-wide leading-6">
#           Designed to democratize data skills in Southeast Asia with accessible tuition options. Career outcome guarantees for our bootcamp programs.
#          </p>
#         </div>
#         <div class="px-4 py-6 border-t border-mischka md:py-4 md:border-l md:border-t-0">
#          <div class="mb-1 p-2 w-8 text-white bg-tradewind rounded-full fill-current">
#           <svg viewbox="0 0 576 512" xmlns="http://www.w3.org/2000/svg">
#            <path d="M528.1 171.5L382 150.2 316.7 17.8c-11.7-23.6-45.6-23.9-57.4 0L194 150.2 47.9 171.5c-26.2 3.8-36.7 36.1-17.7 54.6l105.7 103-25 145.5c-4.5 26.3 23.2 46 46.4 33.7L288 439.6l130.7 68.7c23.2 12.2 50.9-7.4 46.4-33.7l-25-145.5 105.7-103c19-18.5 8.5-50.8-17.7-54.6zM388.6 312.3l23.7 138.4L288 385.4l-124.3 65.3 23.7-138.4-100.6-98 139-20.2 62.2-126 62.2 126 139 20.2-100.6 98z">
#            </path>
#           </svg>
#          </div>
#          <h4 class="leading-2 my-2 text-pickled-bluewood text-sm">
#           One-on-One Mentoring
#          </h4>
#          <p class="text-justify text-tundora text-xs tracking-wide leading-6">
#           Access academic and career guidance from industry professionals throughout your journey.
#          </p>
#         </div>
#         <div class="px-4 py-6 border-t border-mischka md:py-4 md:border-l md:border-t-0">
#          <div class="mb-1 p-2 w-8 text-white bg-tradewind rounded-full fill-current">
#           <svg viewbox="0 0 640 512" xmlns="http://www.w3.org/2000/svg">
#            <path d="M208 352c-2.39 0-4.78.35-7.06 1.09C187.98 357.3 174.35 360 160 360c-14.35 0-27.98-2.7-40.95-6.91-2.28-.74-4.66-1.09-7.05-1.09C49.94 352-.33 402.48 0 464.62.14 490.88 21.73 512 48 512h224c26.27 0 47.86-21.12 48-47.38.33-62.14-49.94-112.62-112-112.62zm-48-32c53.02 0 96-42.98 96-96s-42.98-96-96-96-96 42.98-96 96 42.98 96 96 96zM592 0H208c-26.47 0-48 22.25-48 49.59V96c23.42 0 45.1 6.78 64 17.8V64h352v288h-64v-64H384v64h-76.24c19.1 16.69 33.12 38.73 39.69 64H592c26.47 0 48-22.25 48-49.59V49.59C640 22.25 618.47 0 592 0z">
#            </path>
#           </svg>
#          </div>
#          <h4 class="leading-2 my-2 text-pickled-bluewood text-sm">
#           Project Based Learning
#          </h4>
#          <p class="text-justify text-tundora text-xs tracking-wide leading-6">
#           Learn using hands-on projects that mimic the latest use cases from industry.
#          </p>
#         </div>
#        </section>
#       </section>
#       <section class="bg-white">
#        <div>
#         <div class="container mx-auto p-2 text-center">
#          <h2 class="mb-9 pt-16 text-pickled-bluewood text-5xl">
#           Which Path Will You Choose?
#          </h2>
#          <p class="mx-auto p-2 text-tundora text-base text-center">
#           <span>
#            Accelerated programs that transform your career, depending on your goal and schedule.
#           </span>
#          </p>
#         </div>
#         <div class="text-silver relative md:hidden">
#          <svg class="fill-current ml-3 w-4 h-4 animate-bounce-left-right absolute top-0 right-0" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#           <path d="M190.5 66.9l22.2-22.2c9.4-9.4 24.6-9.4 33.9 0L441 239c9.4 9.4 9.4 24.6 0 33.9L246.6 467.3c-9.4 9.4-24.6 9.4-33.9 0l-22.2-22.2c-9.5-9.5-9.3-25 .4-34.3L311.4 296H24c-13.3 0-24-10.7-24-24v-32c0-13.3 10.7-24 24-24h287.4L190.9 101.2c-9.8-9.3-10-24.8-.4-34.3z">
#           </path>
#          </svg>
#         </div>
#         <div class="flex mt-6 cursor-pointer overflow-x-scroll md:overflow-auto">
#          <article class="pathway-box border-mercury relative m-2 w-72 hover:text-white hover:bg-pickled-bluewood bg-white-lilac border box-content md:m-0 md:w-1/3 md:border-none">
#           <div class="pathway-image relative w-72 h-52 md:w-full md:h-72">
#            <div style="display: block; overflow: hidden; position: absolute; inset: 0px; box-sizing: border-box; margin: 0px;">
#             <img alt="Analytics" decoding="async" sizes="(max-width: 640px) 640px, (max-width: 750px) 750px, (max-width: 828px) 828px, (max-width: 1080px) 1080px, (max-width: 1200px) 1200px, (max-width: 1920px) 1920px, (max-width: 2048px) 2048px, 3840px" src="/_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Analytics_4_ef85e2ce7d.jpg&amp;w=3840&amp;q=75" srcset="/_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Analytics_4_ef85e2ce7d.jpg&amp;w=640&amp;q=75 640w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Analytics_4_ef85e2ce7d.jpg&amp;w=750&amp;q=75 750w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Analytics_4_ef85e2ce7d.jpg&amp;w=828&amp;q=75 828w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Analytics_4_ef85e2ce7d.jpg&amp;w=1080&amp;q=75 1080w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Analytics_4_ef85e2ce7d.jpg&amp;w=1200&amp;q=75 1200w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Analytics_4_ef85e2ce7d.jpg&amp;w=1920&amp;q=75 1920w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Analytics_4_ef85e2ce7d.jpg&amp;w=2048&amp;q=75 2048w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Analytics_4_ef85e2ce7d.jpg&amp;w=3840&amp;q=75 3840w" style="visibility: visible; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: cover; object-position: center top;"/>
#            </div>
#           </div>
#           <div class="px-4">
#            <h4 class="mb-4 text-pickled-bluewood text-2xl">
#             Analytics
#            </h4>
#            <p class="text-pickled-bluewood text-xs tracking-wider leading-6">
#             8-week bootcamp to become a data analyst where I can analyze and present compelling data stories without coding.
#            </p>
#            <button class="learn-more-button flex-column flex my-6 p-0 text-wild-blue-yonder text-xs tracking-wider focus:outline-none uppercase">
#             Learn more
#             <svg class="ml-3 w-4 h-4 fill-current" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#              <path d="M190.5 66.9l22.2-22.2c9.4-9.4 24.6-9.4 33.9 0L441 239c9.4 9.4 9.4 24.6 0 33.9L246.6 467.3c-9.4 9.4-24.6 9.4-33.9 0l-22.2-22.2c-9.5-9.5-9.3-25 .4-34.3L311.4 296H24c-13.3 0-24-10.7-24-24v-32c0-13.3 10.7-24 24-24h287.4L190.9 101.2c-9.8-9.3-10-24.8-.4-34.3z">
#              </path>
#             </svg>
#            </button>
#            <div>
#            </div>
#           </div>
#          </article>
#          <article class="pathway-box border-mercury relative m-2 w-72 hover:text-white hover:bg-pickled-bluewood bg-white-lilac border box-content md:m-0 md:w-1/3 md:border-none">
#           <div class="pathway-image relative w-72 h-52 md:w-full md:h-72">
#            <div style="display: block; overflow: hidden; position: absolute; inset: 0px; box-sizing: border-box; margin: 0px;">
#             <img alt="Data Science" decoding="async" sizes="(max-width: 640px) 640px, (max-width: 750px) 750px, (max-width: 828px) 828px, (max-width: 1080px) 1080px, (max-width: 1200px) 1200px, (max-width: 1920px) 1920px, (max-width: 2048px) 2048px, 3840px" src="/_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Homepage_8_f92eb61ffd.jpg&amp;w=3840&amp;q=75" srcset="/_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Homepage_8_f92eb61ffd.jpg&amp;w=640&amp;q=75 640w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Homepage_8_f92eb61ffd.jpg&amp;w=750&amp;q=75 750w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Homepage_8_f92eb61ffd.jpg&amp;w=828&amp;q=75 828w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Homepage_8_f92eb61ffd.jpg&amp;w=1080&amp;q=75 1080w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Homepage_8_f92eb61ffd.jpg&amp;w=1200&amp;q=75 1200w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Homepage_8_f92eb61ffd.jpg&amp;w=1920&amp;q=75 1920w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Homepage_8_f92eb61ffd.jpg&amp;w=2048&amp;q=75 2048w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Homepage_8_f92eb61ffd.jpg&amp;w=3840&amp;q=75 3840w" style="visibility: visible; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: cover; object-position: center top;"/>
#            </div>
#           </div>
#           <div class="px-4">
#            <h4 class="mb-4 text-pickled-bluewood text-2xl">
#             Data Science
#            </h4>
#            <p class="text-pickled-bluewood text-xs tracking-wider leading-6">
#             12-week fellowship to launch a career in data science where I can build cutting-edge data tools and create predictive data products with code.
#            </p>
#            <button class="learn-more-button flex-column flex my-6 p-0 text-wild-blue-yonder text-xs tracking-wider focus:outline-none uppercase">
#             Learn more
#             <svg class="ml-3 w-4 h-4 fill-current" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#              <path d="M190.5 66.9l22.2-22.2c9.4-9.4 24.6-9.4 33.9 0L441 239c9.4 9.4 9.4 24.6 0 33.9L246.6 467.3c-9.4 9.4-24.6 9.4-33.9 0l-22.2-22.2c-9.5-9.5-9.3-25 .4-34.3L311.4 296H24c-13.3 0-24-10.7-24-24v-32c0-13.3 10.7-24 24-24h287.4L190.9 101.2c-9.8-9.3-10-24.8-.4-34.3z">
#              </path>
#             </svg>
#            </button>
#            <div>
#            </div>
#           </div>
#          </article>
#          <article class="pathway-box border-mercury relative m-2 w-72 hover:text-white hover:bg-pickled-bluewood bg-white-lilac border box-content md:m-0 md:w-1/3 md:border-none">
#           <div class="pathway-image relative w-72 h-52 md:w-full md:h-72">
#            <div style="display: block; overflow: hidden; position: absolute; inset: 0px; box-sizing: border-box; margin: 0px;">
#             <img alt="Data Club" decoding="async" sizes="(max-width: 640px) 640px, (max-width: 750px) 750px, (max-width: 828px) 828px, (max-width: 1080px) 1080px, (max-width: 1200px) 1200px, (max-width: 1920px) 1920px, (max-width: 2048px) 2048px, 3840px" src="/_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Homepage_9_02087dd0b2.jpg&amp;w=3840&amp;q=75" srcset="/_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Homepage_9_02087dd0b2.jpg&amp;w=640&amp;q=75 640w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Homepage_9_02087dd0b2.jpg&amp;w=750&amp;q=75 750w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Homepage_9_02087dd0b2.jpg&amp;w=828&amp;q=75 828w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Homepage_9_02087dd0b2.jpg&amp;w=1080&amp;q=75 1080w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Homepage_9_02087dd0b2.jpg&amp;w=1200&amp;q=75 1200w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Homepage_9_02087dd0b2.jpg&amp;w=1920&amp;q=75 1920w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Homepage_9_02087dd0b2.jpg&amp;w=2048&amp;q=75 2048w, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FNW_Homepage_9_02087dd0b2.jpg&amp;w=3840&amp;q=75 3840w" style="visibility: visible; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%; object-fit: cover; object-position: center top;"/>
#            </div>
#           </div>
#           <div class="px-4">
#            <h4 class="mb-4 text-pickled-bluewood text-2xl">
#             Data Club
#            </h4>
#            <p class="text-pickled-bluewood text-xs tracking-wider leading-6">
#             I want to build up my data skills over time through flexible mentor-led projects where I can explore and discover different topics with peers.
#            </p>
#            <button class="learn-more-button flex-column flex my-6 p-0 text-wild-blue-yonder text-xs tracking-wider focus:outline-none uppercase">
#             Learn more
#             <svg class="ml-3 w-4 h-4 fill-current" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#              <path d="M190.5 66.9l22.2-22.2c9.4-9.4 24.6-9.4 33.9 0L441 239c9.4 9.4 9.4 24.6 0 33.9L246.6 467.3c-9.4 9.4-24.6 9.4-33.9 0l-22.2-22.2c-9.5-9.5-9.3-25 .4-34.3L311.4 296H24c-13.3 0-24-10.7-24-24v-32c0-13.3 10.7-24 24-24h287.4L190.9 101.2c-9.8-9.3-10-24.8-.4-34.3z">
#              </path>
#             </svg>
#            </button>
#            <div>
#            </div>
#           </div>
#          </article>
#         </div>
#        </div>
#       </section>
#       <section class="bg-tradewind">
#        <div class="container mx-auto pt-12 text-center">
#         <div class="grid md:grid-cols-2">
#          <aside class="mb-12">
#           <div style="display:inline-block;max-width:100%;overflow:hidden;position:relative;box-sizing:border-box;margin:0">
#            <div style="box-sizing:border-box;display:block;max-width:100%">
#             <img alt="" aria-hidden="true" role="presentation" src="..." style="max-width:100%;display:block"/>
#            </div>
#            <img alt="Eskwelabs training" decoding="async" src="/_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2Ffuture_proof_team.png&amp;w=1080&amp;q=75" srcset="/_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2Ffuture_proof_team.png&amp;w=384&amp;q=75 1x, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2Ffuture_proof_team.png&amp;w=750&amp;q=75 2x, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2Ffuture_proof_team.png&amp;w=1080&amp;q=75 3x" style="visibility: visible; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%;"/>
#           </div>
#          </aside>
#          <div class="self-center p-4 text-left">
#           <h2 class="mb-6 text-white text-3xl tracking-wider leading-10">
#            Future-proof your team with Eskwelabs
#           </h2>
#           <p class="text-white tracking-wide leading-8">
#            We work with companies to help them build or buy data talent so they can succeed as industries continue to be disrupted by innovation.
#           </p>
#           <a class="hover:bg-pickled-bluewood-darker inline-block w-auto mb-12 mt-6 px-8 py-3 text-white text-xs tracking-wider bg-pickled-bluewood rounded-lg uppercase" href="/for-companies">
#            Partner with us
#           </a>
#          </div>
#         </div>
#        </div>
#       </section>
#       <section class="bg-white">
#        <div class="flex flex-col py-9 w-full md:flex-row">
#         <div class="self-center align-middle p-4 pt-12 w-full text-left md:w-1/3">
#          <div class="md:mx-auto md:w-72">
#           <h2 class="mb-6 text-pickled-bluewood text-3xl tracking-wider leading-10">
#            Recent blogs
#           </h2>
#           <p class="text-tundora text-sm tracking-wide leading-6">
#            <span>
#             Learner stories, project highlights,
#             <br/>
#             Eskwelabs news and more.
#             <br/>
#             For bi-weekly community updates,
#             <br/>
#             sign up for the E is for Eskwelabs newsletter.
#            </span>
#           </p>
#           <a class="hover:bg-tradewind-darker mb-12 mt-6 px-8 py-3 inline-block text-white text-xs tracking-wider bg-tradewind rounded-lg uppercase" href="/blog">
#            See more
#           </a>
#          </div>
#         </div>
#         <div class="text-silver relative md:hidden">
#          <svg class="fill-current ml-3 w-4 h-4 animate-bounce-left-right absolute top-0 right-0" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#           <path d="M190.5 66.9l22.2-22.2c9.4-9.4 24.6-9.4 33.9 0L441 239c9.4 9.4 9.4 24.6 0 33.9L246.6 467.3c-9.4 9.4-24.6 9.4-33.9 0l-22.2-22.2c-9.5-9.5-9.3-25 .4-34.3L311.4 296H24c-13.3 0-24-10.7-24-24v-32c0-13.3 10.7-24 24-24h287.4L190.9 101.2c-9.8-9.3-10-24.8-.4-34.3z">
#           </path>
#          </svg>
#         </div>
#         <div class="flex-column flex py-4 w-full overflow-x-auto md:w-2/3">
#          <article class="blog-post-card flex flex-col m-3 text-left border border-mischka hover:border-pickled-bluewood rounded-lg" style="width:292px">
#           <div style="overflow:hidden;box-sizing:border-box;display:inline-block;position:relative;width:290px;height:182px">
#            <img class="rounded-t-lg" decoding="async" src="/_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FDS_Dan_Blog_Header_b8804f7261.png&amp;w=1080&amp;q=75" srcset="/_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FDS_Dan_Blog_Header_b8804f7261.png&amp;w=384&amp;q=75 1x, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FDS_Dan_Blog_Header_b8804f7261.png&amp;w=640&amp;q=75 2x, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FDS_Dan_Blog_Header_b8804f7261.png&amp;w=1080&amp;q=75 3x" style="visibility: visible; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%;"/>
#           </div>
#           <div class="flex flex-col flex-grow p-4">
#            <h4 class="mb-2 text-pickled-bluewood text-lg font-semibold tracking-normal leading-6">
#             Unlocking Opportunities in Data Science for Social Good
#            </h4>
#            <p class="flex-grow text-tundora text-xs tracking-wide leading-6">
#             "By surrounding yourself with people who are also pursuing data science for good, you will have the opportunity to collaborate and learn from each other to better not just the community you are working for, but also grow as individuals."
#            </p>
#            <div class="flex flex-wrap my-4">
#             <div class="text-terracotta-darker bg-terracotta-200 border-terracotta-darker flex items-center justify-center m-1 px-2 py-1 font-medium border rounded-full">
#              <span class="flex-initial max-w-full text-xs font-normal leading-none">
#               Data Science Fellowship
#              </span>
#             </div>
#             <div class="text-terracotta-darker bg-terracotta-200 border-terracotta-darker flex items-center justify-center m-1 px-2 py-1 font-medium border rounded-full">
#              <span class="flex-initial max-w-full text-xs font-normal leading-none">
#               Data for Good
#              </span>
#             </div>
#            </div>
#            <a class="learn-more-button flex-column hover:text-tradewind-darker flex p-0 text-tradewind text-xs tracking-wider focus:outline-none uppercase" href="/blog/unlocking-opportunities-in-data-science-for-social-good">
#             Read more
#             <svg class="ml-3 w-4 h-4 fill-current" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#              <path d="M190.5 66.9l22.2-22.2c9.4-9.4 24.6-9.4 33.9 0L441 239c9.4 9.4 9.4 24.6 0 33.9L246.6 467.3c-9.4 9.4-24.6 9.4-33.9 0l-22.2-22.2c-9.5-9.5-9.3-25 .4-34.3L311.4 296H24c-13.3 0-24-10.7-24-24v-32c0-13.3 10.7-24 24-24h287.4L190.9 101.2c-9.8-9.3-10-24.8-.4-34.3z">
#              </path>
#             </svg>
#            </a>
#           </div>
#          </article>
#          <article class="blog-post-card flex flex-col m-3 text-left border border-mischka hover:border-pickled-bluewood rounded-lg" style="width:292px">
#           <div style="overflow:hidden;box-sizing:border-box;display:inline-block;position:relative;width:290px;height:182px">
#            <img class="rounded-t-lg" decoding="async" src="/_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FESK_ADM_Blog_Reach_out_about_program_b13181c667.png&amp;w=1080&amp;q=75" srcset="/_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FESK_ADM_Blog_Reach_out_about_program_b13181c667.png&amp;w=384&amp;q=75 1x, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FESK_ADM_Blog_Reach_out_about_program_b13181c667.png&amp;w=640&amp;q=75 2x, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FESK_ADM_Blog_Reach_out_about_program_b13181c667.png&amp;w=1080&amp;q=75 3x" style="visibility: visible; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%;"/>
#           </div>
#           <div class="flex flex-col flex-grow p-4">
#            <h4 class="mb-2 text-pickled-bluewood text-lg font-semibold tracking-normal leading-6">
#             How do I reach out about my Program Application?
#            </h4>
#            <p class="flex-grow text-tundora text-xs tracking-wide leading-6">
#             Here is a round up of questions that you may have as you go through our 3-step admissions process. We hope this guide is helpful for all aspiring Eskwelabs students.
#            </p>
#            <div class="flex flex-wrap my-4">
#             <div class="text-terracotta-darker bg-terracotta-200 border-terracotta-darker flex items-center justify-center m-1 px-2 py-1 font-medium border rounded-full">
#              <span class="flex-initial max-w-full text-xs font-normal leading-none">
#               Data Science Fellowship
#              </span>
#             </div>
#             <div class="text-terracotta-darker bg-terracotta-200 border-terracotta-darker flex items-center justify-center m-1 px-2 py-1 font-medium border rounded-full">
#              <span class="flex-initial max-w-full text-xs font-normal leading-none">
#               Data Analytics Bootcamp
#              </span>
#             </div>
#            </div>
#            <a class="learn-more-button flex-column hover:text-tradewind-darker flex p-0 text-tradewind text-xs tracking-wider focus:outline-none uppercase" href="/blog/how-do-i-reach-out-about-my-program-application">
#             Read more
#             <svg class="ml-3 w-4 h-4 fill-current" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#              <path d="M190.5 66.9l22.2-22.2c9.4-9.4 24.6-9.4 33.9 0L441 239c9.4 9.4 9.4 24.6 0 33.9L246.6 467.3c-9.4 9.4-24.6 9.4-33.9 0l-22.2-22.2c-9.5-9.5-9.3-25 .4-34.3L311.4 296H24c-13.3 0-24-10.7-24-24v-32c0-13.3 10.7-24 24-24h287.4L190.9 101.2c-9.8-9.3-10-24.8-.4-34.3z">
#              </path>
#             </svg>
#            </a>
#           </div>
#          </article>
#          <article class="blog-post-card flex flex-col m-3 text-left border border-mischka hover:border-pickled-bluewood rounded-lg" style="width:292px">
#           <div style="overflow:hidden;box-sizing:border-box;display:inline-block;position:relative;width:290px;height:182px">
#            <img class="rounded-t-lg" decoding="async" src="/_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FEsk_Blog_Terms_5ba994e413.png&amp;w=1080&amp;q=75" srcset="/_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FEsk_Blog_Terms_5ba994e413.png&amp;w=384&amp;q=75 1x, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FEsk_Blog_Terms_5ba994e413.png&amp;w=640&amp;q=75 2x, /_next/image?url=https%3A%2F%2Fassets.eskwelabs.com%2FEsk_Blog_Terms_5ba994e413.png&amp;w=1080&amp;q=75 3x" style="visibility: visible; position: absolute; inset: 0px; box-sizing: border-box; padding: 0px; border: none; margin: auto; display: block; width: 0px; height: 0px; min-width: 100%; max-width: 100%; min-height: 100%; max-height: 100%;"/>
#           </div>
#           <div class="flex flex-col flex-grow p-4">
#            <h4 class="mb-2 text-pickled-bluewood text-lg font-semibold tracking-normal leading-6">
#             Eskwelabs Admissions: Definition of Terms
#            </h4>
#            <p class="flex-grow text-tundora text-xs tracking-wide leading-6">
#             Here is a compilation of the most frequently used terms related to the Eskwelabs admissions process. Read this short guide to get more clarity on the different words we use such as, Application, Admissions, Assessment, and more.
#            </p>
#           </a>
#          </li>
#          <li class="py-2 inline-block ml-2 sm:ml-9">
#           <a class="link" href="/privacy">
#            Privacy Policy
#           </a>
#          </li>
#         </ul>
#         <ul class="uppercase text-xs my-6">
#          <li class="py-2 inline-block">
#           <a class="link" href="https://www.facebook.com/eskwelabs" rel="noreferrer" target="_blank" title="Eskwelabs on Facebook">
#            <svg class="w-4 h-4 fill-current" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#             <path d="M400 32H48A48 48 0 0 0 0 80v352a48 48 0 0 0 48 48h137.25V327.69h-63V256h63v-54.64c0-62.15 37-96.48 93.67-96.48 27.14 0 55.52 4.84 55.52 4.84v61h-31.27c-30.81 0-40.42 19.12-40.42 38.73V256h68.78l-11 71.69h-57.78V480H400a48 48 0 0 0 48-48V80a48 48 0 0 0-48-48z">
#             </path>
#            </svg>
#           </a>
#          </li>
#          <li class="py-2 inline-block ml-8">
#           <a class="link" href="https://instagram.com/eskwelabs_ph" rel="noreferrer" target="_blank" title="Eskwelabs on Instagram">
#            <svg class="w-4 h-4 fill-current" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#             <path d="M224.1 141c-63.6 0-114.9 51.3-114.9 114.9s51.3 114.9 114.9 114.9S339 319.5 339 255.9 287.7 141 224.1 141zm0 189.6c-41.1 0-74.7-33.5-74.7-74.7s33.5-74.7 74.7-74.7 74.7 33.5 74.7 74.7-33.6 74.7-74.7 74.7zm146.4-194.3c0 14.9-12 26.8-26.8 26.8-14.9 0-26.8-12-26.8-26.8s12-26.8 26.8-26.8 26.8 12 26.8 26.8zm76.1 27.2c-1.7-35.9-9.9-67.7-36.2-93.9-26.2-26.2-58-34.4-93.9-36.2-37-2.1-147.9-2.1-184.9 0-35.8 1.7-67.6 9.9-93.9 36.1s-34.4 58-36.2 93.9c-2.1 37-2.1 147.9 0 184.9 1.7 35.9 9.9 67.7 36.2 93.9s58 34.4 93.9 36.2c37 2.1 147.9 2.1 184.9 0 35.9-1.7 67.7-9.9 93.9-36.2 26.2-26.2 34.4-58 36.2-93.9 2.1-37 2.1-147.8 0-184.8zM398.8 388c-7.8 19.6-22.9 34.7-42.6 42.6-29.5 11.7-99.5 9-132.1 9s-102.7 2.6-132.1-9c-19.6-7.8-34.7-22.9-42.6-42.6-11.7-29.5-9-99.5-9-132.1s-2.6-102.7 9-132.1c7.8-19.6 22.9-34.7 42.6-42.6 29.5-11.7 99.5-9 132.1-9s102.7-2.6 132.1 9c19.6 7.8 34.7 22.9 42.6 42.6 11.7 29.5 9 99.5 9 132.1s2.7 102.7-9 132.1z">
#             </path>
#            </svg>
#           </a>
#          </li>
#          <li class="py-2 inline-block ml-8">
#           <a class="link" href="https://twitter.com/eskwelabs" rel="noreferrer" target="_blank" title="Eskwelabs on Twitter">
#            <svg class="w-4 h-4 fill-current" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#             <path d="M400 32H48C21.5 32 0 53.5 0 80v352c0 26.5 21.5 48 48 48h352c26.5 0 48-21.5 48-48V80c0-26.5-21.5-48-48-48zm-48.9 158.8c.2 2.8.2 5.7.2 8.5 0 86.7-66 186.6-186.6 186.6-37.2 0-71.7-10.8-100.7-29.4 5.3.6 10.4.8 15.8.8 30.7 0 58.9-10.4 81.4-28-28.8-.6-53-19.5-61.3-45.5 10.1 1.5 19.2 1.5 29.6-1.2-30-6.1-52.5-32.5-52.5-64.4v-.8c8.7 4.9 18.9 7.9 29.6 8.3a65.447 65.447 0 0 1-29.2-54.6c0-12.2 3.2-23.4 8.9-33.1 32.3 39.8 80.8 65.8 135.2 68.6-9.3-44.5 24-80.6 64-80.6 18.9 0 35.9 7.9 47.9 20.7 14.8-2.8 29-8.3 41.6-15.8-4.9 15.2-15.2 28-28.8 36.1 13.2-1.4 26-5.1 37.8-10.2-8.9 13.1-20.1 24.7-32.9 34z">
#             </path>
#            </svg>
#           </a>
#          </li>
#          <li class="py-2 inline-block ml-8">
#           <a class="link" href="https://www.youtube.com/channel/UCNQMYn4R6Stvn0tu7QWqxPA" rel="noreferrer" target="_blank" title="Eskwelabs on Youtube">
#            <svg class="w-4 h-4 fill-current" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#             <path d="M186.8 202.1l95.2 54.1-95.2 54.1V202.1zM448 80v352c0 26.5-21.5 48-48 48H48c-26.5 0-48-21.5-48-48V80c0-26.5 21.5-48 48-48h352c26.5 0 48 21.5 48 48zm-42 176.3s0-59.6-7.6-88.2c-4.2-15.8-16.5-28.2-32.2-32.4C337.9 128 224 128 224 128s-113.9 0-142.2 7.7c-15.7 4.2-28 16.6-32.2 32.4-7.6 28.5-7.6 88.2-7.6 88.2s0 59.6 7.6 88.2c4.2 15.8 16.5 27.7 32.2 31.9C110.1 384 224 384 224 384s113.9 0 142.2-7.7c15.7-4.2 28-16.1 32.2-31.9 7.6-28.5 7.6-88.1 7.6-88.1z">
#             </path>
#            </svg>
#           </a>
#          </li>
#          <li class="py-2 inline-block ml-8">
#           <a class="link" href="https://www.linkedin.com/company/eskwelabs/" rel="noreferrer" target="_blank" title="Eskwelabs on LinkedIn">
#            <svg class="w-4 h-4 fill-current" viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
#             <path d="M416 32H31.9C14.3 32 0 46.5 0 64.3v383.4C0 465.5 14.3 480 31.9 480H416c17.6 0 32-14.5 32-32.3V64.3c0-17.8-14.4-32.3-32-32.3zM135.4 416H69V202.2h66.5V416zm-33.2-243c-21.3 0-38.5-17.3-38.5-38.5S80.9 96 102.2 96c21.2 0 38.5 17.3 38.5 38.5 0 21.3-17.2 38.5-38.5 38.5zm282.1 243h-66.4V312c0-24.8-.5-56.7-34.5-56.7-34.6 0-39.9 27-39.9 54.9V416h-66.4V202.2h63.7v29.2h.9c8.9-16.8 30.6-34.5 62.9-34.5 67.2 0 79.7 44.3 79.7 101.9V416z">
#             </path>
#            </svg>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="w-full xl:w-1/3">
#         <div>
#          <h5 class="pb-6 uppercase">
#           Updates from Eskwelabs
#          </h5>
#          <p class="mb-12 text-xs">
#           Subscribe to our newsletter receive updates and insights on future of learning.
#           <br/>
#           For admission enquiries, please contact
#           <!-- -->
#           <a class="hover:underline" href="mailto:admissions@eskwelabs.com">
#            <strong>
#             <i>
#              admissions@eskwelabs.com
#             </i>
#            </strong>
#           </a>
#           .
#          </p>
#          <div class="flex flex-row mb-4">
#           <input class="focus:shadow-outline p-3 w-full leading-tight border border-tradewind rounded-l-lg focus:outline-none shadow appearance-none text-tundora text-sm" id="email" placeholder="Enter your email address..." type="text" value=""/>
#           <a class="inline-block align-middle px-6 pt-2 bg-tradewind rounded-r-lg" href="#" rel="noreferrer" target="_blank">
#            Go
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="bg-pickled-bluewood-darkest">
#       <div class="text-center mt-8 py-4 text-bermuda-gray text-2xs tracking-wider uppercase">
#        All Rights Reserved. Copyright © Eskwelabs
#        <!-- -->
#        2021
#        <!-- -->
#        .
#       </div>
#      </div>
#     </footer>
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{"initialApolloState":{"Home:5fe8b5f1bf0f822ed306f55c":{"id":"5fe8b5f1bf0f822ed306f55c","__typename":"Home","heroTitle":"The future of work is data","heroSubtitle":"Eskwelabs is an online data upskilling school for people and teams in Southeast Asia\n","heroButtonIndividualsText":"For Individuals","heroButtonCompaniesText":"For Companies","howWeWorkTitle":"What We Offer","howWeWorkDescription":"Access opportunities in the future of work through accessible data skills that are high in-demand as the amount of data in the world increases exponentially. ","chooseYourPathTitle":"Which Path Will You Choose?","chooseYourPathSubtitle":"Accelerated programs that transform your career, depending on your goal and schedule.","futureProofYourTeamTitle":"Future-proof your team with Eskwelabs","futureProofYourTeamSubtitle":"We work with companies to help them build or buy data talent so they can succeed as industries continue to be disrupted by innovation. ","recentBlogPostTitle":"Recent blogs","recentBlogPostDescription":"Learner stories, project highlights, \u003cbr/\u003e\nEskwelabs news and more.\u003cbr/\u003e\nFor bi-weekly community updates,\u003cbr/\u003e \nsign up for the E is for Eskwelabs newsletter.","joinTheCommunityTitle":"Join the Community","notSureWhereToStartTitle":"Not sure where to start?","notSureWhereToStartButtonText":"Find your path"},"ChooseYourPath:5fddbcec0b7629001ba88bdc":{"id":"5fddbcec0b7629001ba88bdc","__typename":"ChooseYourPath","image":{"__typename":"UploadFile","url":"https://eskwelabs-assets.s3.ap-southeast-1.amazonaws.com/NW_Analytics_4_ef85e2ce7d.jpg","alternativeText":""},"title":"Analytics","description":"8-week bootcamp to become a data analyst where I can analyze and present compelling data stories without coding.","order":1,"path_course_items({\"sort\":\"order:asc\"})":[{"__typename":"PathCourseItem","image":{"__typename":"UploadFile","url":"https://eskwelabs-assets.s3.ap-southeast-1.amazonaws.com/241_A8188_1_ab16b53cbf.jpg","alternativeText":""},"title":"Aral-Aral Free Prep Course","description":"Eskwelabs’ free learning community for those interested in exploring a data career path or acquiring data literacy.","order":1,"buttonText":"Learn More","buttonURL":"/aral-aral"},{"__typename":"PathCourseItem","image":{"__typename":"UploadFile","url":"https://eskwelabs-assets.s3.ap-southeast-1.amazonaws.com/241_A8190_e13f2e142c.jpg","alternativeText":""},"title":"Data Analytics Bootcamp","description":"An easy entry into a data analyst career through this 8-week part-time program for anyone who wants to use data to tell stories and answer business questions. Coding not required! ","order":2,"buttonText":"Learn More","buttonURL":"/data-analytics-bootcamp"}]},"ChooseYourPath:5fddbd110b7629001ba88bdd":{"id":"5fddbd110b7629001ba88bdd","__typename":"ChooseYourPath","image":{"__typename":"UploadFile","url":"https://eskwelabs-assets.s3.ap-southeast-1.amazonaws.com/NW_Homepage_8_f92eb61ffd.jpg","alternativeText":""},"title":"Data Science","description":"12-week fellowship to launch a career in data science where I can build cutting-edge data tools and create predictive data products with code.","order":2,"path_course_items({\"sort\":\"order:asc\"})":[{"__typename":"PathCourseItem","image":{"__typename":"UploadFile","url":"https://eskwelabs-assets.s3.ap-southeast-1.amazonaws.com/IMG_9113_2868bf628c.JPG","alternativeText":""},"title":"Aral-Aral+ Python Code-Along Notebooks","description":"Access code-along 70+ videos within 14 Juypter Notebooks that cover the fundamentals of Python, and Statistics applications for data science at your own pace.","order":1,"buttonText":"Learn More","buttonURL":"/aral-aral-plus"},{"__typename":"PathCourseItem","image":{"__typename":"UploadFile","url":"https://eskwelabs-assets.s3.ap-southeast-1.amazonaws.com/Uploan_3_2_300ae10e56.jpg","alternativeText":""},"title":"Data Science Fellowship","description":"Our flagship 12-week part-time bootcamp that launches the ...
#   </script>
#   <script nomodule="" src="/_next/static/chunks/polyfills-780bbb25ca31cca5194f.js">
#   </script>
#   <script async="" src="/_next/static/chunks/main-63b4da518a06488ffb50.js">
#   </script>
#   <script async="" src="/_next/static/chunks/webpack-cb40b0c47a0047965a08.js">
#   </script>
#   <script async="" src="/_next/static/chunks/framework.9707fddd9ae5927c17c3.js">
#   </script>
#   <script async="" src="/_next/static/chunks/commons.10a9314202ca8629b33c.js">
#   </script>
#   <script async="" src="/_next/static/chunks/74e6a81e666a4a4de28a244888c091c5eb13391e.99073904f647c8c9f0f3.js">
#   </script>
#   <script async="" src="/_next/static/chunks/pages/_app-68ea9945159d2922b21a.js">
#   </script>
#   <script async="" src="/_next/static/chunks/35b6b5a93b9b89ca812d02ec8c2964793e86ba01.5be50b8eaed33eb905de.js">
#   </script>
#   <script async="" src="/_next/static/chunks/pages/index-254fb798efa03823cc2b.js">
#   </script>
#   <script async="" src="/_next/static/CXOVLslFmjnkwRdXgHUWh/_buildManifest.js">
#   </script>
#   <script async="" src="/_next/static/CXOVLslFmjnkwRdXgHUWh/_ssgManifest.js">
#   </script>
#   <iframe id="_hjRemoteVarsFrame" name="_hjRemoteVarsFrame" src="https://vars.hotjar.com/box-469cf41adb11dc78be68c1ae7f9457a4.html" style="display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;" title="_hjRemoteVarsFrame">
#   </iframe>
#   <script src="/_next/static/chunks/47f4fe5087d09f58e9f22a4202f3069e8af1fccf.9792c339b179631a910c.js">
#   </script>
#   <script src="/_next/static/chunks/pages/about-99aae1f9f114f267fa55.js">
#   </script>
#   <script src="/_next/static/chunks/2dc2263451bebce49644f8d901e6a7cd4fbc31ef.365508483d4ac1f615e6.js">
#   </script>
#   <script src="/_next/static/chunks/pages/for-companies-4c648f08fb6b61789779.js">
#   </script>
#   <script src="/_next/static/chunks/pages/careers-243a9b95d31f56266446.js">
#   </script>
#   <script src="/_next/static/chunks/pages/blog-db0c0aa50467462bc1cf.js">
#   </script>
#   <script src="/_next/static/chunks/6eaf201f56d173ece524a6c619a74538491fc9b5.524b501f32184771b75a.js">
#   </script>
#   <script src="/_next/static/chunks/pages/aral-aral-a952719a4b0d95b0595c.js">
#   </script>
#   <script src="/_next/static/chunks/pages/aral-aral-plus-bb1bd7d5b9eed3582e91.js">
#   </script>
#   <script src="/_next/static/chunks/pages/data-analytics-bootcamp-a82282c115e6c525e3ed.js">
#   </script>
#   <script src="/_next/static/chunks/pages/data-science-fellowship-14b0aac3f918cdc1e7fc.js">
#   </script>
#   <script src="/_next/static/chunks/pages/data-club-42645142e76ce1c7dbc4.js">
#   </script>
#   <script src="/_next/static/chunks/pages/blog/%5Bslug%5D-ba01b9aefea2eb9744e0.js">
#   </script>
#   <script src="/_next/static/chunks/pages/privacy-6ef864fceb27014cfe64.js">
#   </script>
#  </body>
# </html>

# %%
contents = soup.find('p', class_='findList')

# %%
contents
# Out:
# <table class="findList">
# <tbody><tr class="findResult odd"> <td class="primary_photo"> <a href="/title/tt0974015/?ref_=fn_al_tt_1"><img src="https://m.media-amazon.com/images/M/MV5BYWVhZjZkYTItOGIwYS00NmRkLWJlYjctMWM0ZjFmMDU4ZjEzXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX32_CR0,0,32,44_AL_.jpg"/></a> </td> <td class="result_text"> <a href="/title/tt0974015/?ref_=fn_al_tt_1">Justice League</a> (2017) </td> </tr><tr class="findResult even"> <td class="primary_photo"> <a href="/title/tt0275137/?ref_=fn_al_tt_2"><img src="https://m.media-amazon.com/images/M/MV5BMDE2ODk0ZTctMGI4Ni00ODgwLTk4OTAtOGNiNjZkMzI3NTY0XkEyXkFqcGdeQXVyOTgwMzk1MTA@._V1_UX32_CR0,0,32,44_AL_.jpg"/></a> </td> <td class="result_text"> <a href="/title/tt0275137/?ref_=fn_al_tt_2">Justice League</a> (2001) (TV Series) </td> </tr><tr class="findResult odd"> <td class="primary_photo"> <a href="/title/tt11417588/?ref_=fn_al_tt_3"><img src="https://m.media-amazon.com/images/S/sash/85lhIiFCmSScRzu.png"/></a> </td> <td class="result_text"> <a href="/title/tt11417588/?ref_=fn_al_tt_3">Justice League</a> (2017) (TV Episode) <br/> <small>- Season 4 <span class="ghost">|</span> Episode 2 </small> <br/><small>- <a href="/title/tt11225340/?ref_=fn_al_tt_3a">Annoying Orange: Trailer Trashed</a> (2014) (TV Series) </small> </td> </tr><tr class="findResult even"> <td class="primary_photo"> <a href="/title/tt12361974/?ref_=fn_al_tt_4"><img src="https://m.media-amazon.com/images/M/MV5BYjI3NDg0ZTEtMDEwYS00YWMyLThjYjktMTNlM2NmYjc1OGRiXkEyXkFqcGdeQXVyMTEyMjM2NDc2._V1_UX32_CR0,0,32,44_AL_.jpg"/></a> </td> <td class="result_text"> <a href="/title/tt12361974/?ref_=fn_al_tt_4">Zack Snyder's Justice League</a> (2021) </td> </tr><tr class="findResult odd"> <td class="primary_photo"> <a href="/title/tt11079148/?ref_=fn_al_tt_5"><img src="https://m.media-amazon.com/images/M/MV5BZDNjMjE5YmUtOTUwOC00MjAyLWJmMzktZjlkMjQyYzNiNmU3XkEyXkFqcGdeQXVyNTA4NzExMDg@._V1_UX32_CR0,0,32,44_AL_.jpg"/></a> </td> <td class="result_text"> <a href="/title/tt11079148/?ref_=fn_al_tt_5">Justice League Dark: Apokolips War</a> (2020) (Video) </td> </tr></tbody></table>

# %%
y = contents.find_all('a')
y
# Out:
# [<a href="/title/tt0974015/?ref_=fn_al_tt_1"><img src="https://m.media-amazon.com/images/M/MV5BYWVhZjZkYTItOGIwYS00NmRkLWJlYjctMWM0ZjFmMDU4ZjEzXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX32_CR0,0,32,44_AL_.jpg"/></a>,
#  <a href="/title/tt0974015/?ref_=fn_al_tt_1">Justice League</a>,
#  <a href="/title/tt0275137/?ref_=fn_al_tt_2"><img src="https://m.media-amazon.com/images/M/MV5BMDE2ODk0ZTctMGI4Ni00ODgwLTk4OTAtOGNiNjZkMzI3NTY0XkEyXkFqcGdeQXVyOTgwMzk1MTA@._V1_UX32_CR0,0,32,44_AL_.jpg"/></a>,
#  <a href="/title/tt0275137/?ref_=fn_al_tt_2">Justice League</a>,
#  <a href="/title/tt11417588/?ref_=fn_al_tt_3"><img src="https://m.media-amazon.com/images/S/sash/85lhIiFCmSScRzu.png"/></a>,
#  <a href="/title/tt11417588/?ref_=fn_al_tt_3">Justice League</a>,
#  <a href="/title/tt11225340/?ref_=fn_al_tt_3a">Annoying Orange: Trailer Trashed</a>,
#  <a href="/title/tt12361974/?ref_=fn_al_tt_4"><img src="https://m.media-amazon.com/images/M/MV5BYjI3NDg0ZTEtMDEwYS00YWMyLThjYjktMTNlM2NmYjc1OGRiXkEyXkFqcGdeQXVyMTEyMjM2NDc2._V1_UX32_CR0,0,32,44_AL_.jpg"/></a>,
#  <a href="/title/tt12361974/?ref_=fn_al_tt_4">Zack Snyder's Justice League</a>,
#  <a href="/title/tt11079148/?ref_=fn_al_tt_5"><img src="https://m.media-amazon.com/images/M/MV5BZDNjMjE5YmUtOTUwOC00MjAyLWJmMzktZjlkMjQyYzNiNmU3XkEyXkFqcGdeQXVyNTA4NzExMDg@._V1_UX32_CR0,0,32,44_AL_.jpg"/></a>,
#  <a href="/title/tt11079148/?ref_=fn_al_tt_5">Justice League Dark: Apokolips War</a>]

# %%
z = []

for i in y:
    z.append(i.get_text())

# %%
z
# Out:
# ['',
#  'Justice League',
#  '',
#  'Justice League',
#  '',
#  'Justice League',
#  'Annoying Orange: Trailer Trashed',
#  '',
#  "Zack Snyder's Justice League",
#  '',
#  'Justice League Dark: Apokolips War']

# %%
w = [non_empty for non_empty in z if non_empty != '']
w
# Out:
# ['Justice League',
#  'Justice League',
#  'Justice League',
#  'Annoying Orange: Trailer Trashed',
#  "Zack Snyder's Justice League",
#  'Justice League Dark: Apokolips War']
